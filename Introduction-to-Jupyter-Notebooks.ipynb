# %% [markdown]
# # Welcome to your first Jupyter Notebook in Google Colab! 😄
#
# In this course, we will learn the basics of programming using Python 3, and will use Jupyter Notebooks (this document) in the process.
#
# The purpose of this Jupyter Notebook is to get you started using Python and Jupyter Notebooks for routine coding activities. This introduction assumes this is your first exposure to Python or Jupyter notebooks.

# %% [markdown]
# # What are Jupyter Notebooks?
#
# [Jupyter notebooks](https://jupyter.org/) are documents that can be viewed and executed inside any modern web browser. For this course, we will use the [Google Colaboratory (or 'Colab')](https://colab.research.google.com/) implementation of Jupyter. Since you're reading this notebook, you already know how to view a Jupyter notebook. The next step is to learn how to execute code that may be embedded in a Jupyter notebook.
#
# To execute Python code in a notebook you will need access to a Python kernel. A kernel is simply a program that runs in the background, maintains workspace memory for variables and functions, and executes Python code. The kernel can be located on the same laptop as your web browser or located in an online cloud service (Google Colab).
#
# **Important Note Regarding Versions** There are two versions of Python in widespread use. Version 2.7 released in 2010, which was the last release of the 2.x series. Version 3.10 is the most recent release of the 3.x series which represents the future direction of language. It has taken years for the major scientific libraries to complete the transition from 2.x to 3.x, but it is now safe to recommend Python 3.x for widespread use. So for this course be sure to use version 3.x of the Python language (latest 3.10).

# %% [markdown]
# # How to use Jupyter Notebooks

# %% [markdown]
# ## Copying Notebooks to your personal drive
#
# In this course the instructor will provide Notebooks to you as shared Google Colab files. To use and edit these files, you will have to first **copy this file to your own personal Drive** (File --> Save a Copy in Drive). Note that these notebooks will be restricted to Utah State University access, so please use your USU Gmail account.
#
# Try it now; then read through the rest of this document and try some editing of your own!

# %% [markdown]
# ## Getting started
# The document you are reading is not a static web page, but an interactive environment called a **Colab notebook** that lets you write and execute code.
#
# Cells, or blocks, can contain either text or code. This block contains only text. Double-click on this text; you will then see the editor panel next to the formatted text. Click on another cell to exit the editor mode.
#
# Below is an example of a **code cell** with a short Python script that computes a value, stores it in a variable, and prints the result:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# To execute the code in the above cell, select it with a click and then either press the play button to the left of the code, or use the keyboard shortcut "Command/Ctrl+Enter". To edit the code, just click the cell and start editing.
#
# Variables that you define in one cell can later be used in other cells:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# When you create your own Colab notebooks, they are stored in your Google Drive account. You can easily share your Colab notebooks with co-workers or friends, allowing them to comment on your notebooks or even edit them. To create a new Colab notebook you can use the File menu above.
#
# Above, the importance of Python versions was noted. The code block below can be executed to check your Python version being used in your notebook (we will use the Colab default):

# %%
import sys
print(sys.version)
# Out:
# 3.7.13 (default, Apr 24 2022, 01:04:09)
# [GCC 7.5.0]

# %% [markdown]
# Try adding a new code block or text block below!

# %%
y = 6+6

# %% [markdown]
# Text here!
