# %%
import numpy as np

arr = np.array([['a','a','a'], ['b', 'b', 'b']])
np.shape(arr)
# Out:
# (2, 3)

# %%
a1D = np.array([1, 2, 3, 4])
a2D = np.array([[1, 2], [3, 4]])
a3D = np.array([[[1, 2], [3, 4]], [[5, 6], [7, 8]]])

print(np.shape(a1D))
print(np.shape(a2D))
print(np.shape(a3D))
# Out:
# (4,)
# (2, 2)
# (2, 2, 2)
